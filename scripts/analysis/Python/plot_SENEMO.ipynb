# %% [markdown]
# import sys
# import socket
# isliv = 'livljobs' in socket.gethostname()
# if isliv:
#  sys.path.insert(0,'/login/jholt/work/Git/COAsT/')
# else:
#  sys.path.insert(0,'/home/users/jholt/work/Git/COAsT/')
#
# import matplotlib.pylab as plt
# import coast
# import numpy as np

# %%
dpath='/gws/nopw/j04/class_vol2/senemo/jdha/SHORT_TESTS/'
fn_nemo_dat = dpath + '/EXP_MES/SENEMO_1m_19810101_19811231_grid_T_198108-198108.nc'
fn_nemo_dom = dpath + '/EXP_MES/domain_cfg_r015-r010_007_004v2.nc'
fn_config_t_grid='/home//users/jholt/work/Git/COAsT/config/example_nemo_grid_t.json'
nemo_t1 = coast.Gridded(fn_data = fn_nemo_dat, fn_domain = fn_nemo_dom, config=fn_config_t_grid)

fn_nemo_dat = dpath + 'EXP_MES_WAV/SENEMO_1m_19810101_19811231_grid_T_198108-198108.nc'
nemo_t2 = coast.Gridded(fn_data = fn_nemo_dat, fn_domain = fn_nemo_dom, config=fn_config_t_grid)

fn_nemo_dat = dpath + 'EXP_MES_WAV_NTM/SENEMO_1m_19810101_19811231_grid_T_198108-198108.nc'
nemo_t3 = coast.Gridded(fn_data = fn_nemo_dat, fn_domain = fn_nemo_dom, config=fn_config_t_grid)

# %%
dpath='/gws/nopw/j04/class_vol2/senemo/cwilso01/senemo/EXP_REF_NOTIDE/means/monthly/'
fn_nemo_dat = dpath + 'SENEMO_1m_19810101_19811231_grid_T_198108-198108.nc'
fn_nemo_dom = dpath + 'domcfg_eORCA025_v2.nc'
nemo_t4 = coast.Gridded(fn_data = fn_nemo_dat, fn_domain = fn_nemo_dom, config=fn_config_t_grid)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/coast_dev/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/miniconda3/envs/coast_dev/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/gws/nopw/j04/class_vol2/senemo/cwilso01/senemo/EXP_REF_NOTIDE/means/monthly/domcfg_eORCA025_v2.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# Temperature profiles in North Sea

# %%
j=950
i=1140

T1=nemo_t1.dataset.variables['thetao_con'].values[0,:,j,i]
T2=nemo_t2.dataset.variables['thetao_con'].values[0,:,j,i]
T3=nemo_t3.dataset.variables['thetao_con'].values[0,:,j,i]
Z1=nemo_t1.dataset.coords['depth_0'].values[:,j,i]
plt.plot(T1,-Z1,T2,-Z1,T3,-Z1)

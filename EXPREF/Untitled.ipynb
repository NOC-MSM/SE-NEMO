# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import xarray as xr
from netCDF4 import Dataset

# %%
file = "/work/n01/n01/jdha/scratch/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST_H/output.abort.nc"
ds = xr.open_dataset(file)

# %%
ds.vosaline[0,0,:,:].plot()

# %%
file = "/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg.nc"
ds = xr.open_dataset(file)

# %%
cs = ds.closea_mask

# %%
file_mes = "/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/INPUTS/domain_cfg_r018-010-010_glo-r018-010_ant_opt_v3_notaper.nc"
ds_mes = xr.open_dataset(file_mes)

# %%
ds_mes.top_level[0,:,:].plot()

# %%
ds_new.top_level[0,:,:].plot()

# %%
ds_new.top_level[0,5:200:25,200] = 1
ds_new.bottom_level[0,5:200:25,200] = 5

# %%
ds_new.bottom_level[0,0:400,0:400].plot(vmin=0, vmax=5)

# %%
ds_new.top_level[0,0:400,0:400].plot(vmin=0, vmax=1)

# %%
ds_new.to_netcdf('/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_mes.nc')

# %%
ds_zps_new=ds

# %%
ds_zps_new.top_level[0,5:200:25,200] = 1
ds_zps_new.bottom_level[0,5:200:25,200] = 5

# %%
ds_zps_new.to_netcdf('/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_zps2.nc')

# %%
ds_zps_new.close()
ds_new.close()

# %%
ds=xr.open_dataset('/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_zps2.nc')
ds_new=ds

# %%
ds_new.closea_mask[5:200:25,200] = 0

# %%
ds_new.to_netcdf('/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_zps3.nc')

# %%
ds_new.close()

# %%
ds_new=xr.open_dataset('/work/n01/n01/jdha/test_deploy_ompi/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_mes.nc')

# %%
ds_new.bottom_level[0,0:400,0:400].plot(vmin=0, vmax=6)

# %%
ds_new.e3t_0[0,0,:,:].plot()

# %%
ds=xr.open_dataset('/work/n01/n01/acc/NEMO/r4.0.5/dev_r4.0.5_NERC_latest/cfgs/GO8ish_MEDUSA/EXP_B002/domcfg_out.nc')

# %%
ds.top_level[0,0:400,0:400].plot(vmin=0, vmax=1)

# %%
ds.closea_mask[0:200,0:200].plot()

# %%
nc = Dataset('/work/n01/n01/jdha/scratch/test_deploy_cray/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_mes.nc',mode='a')

# %%
tl = nc.variables['top_level'][:]

# %%
tl[0,5:200:25,200] = 1

# %%
nc.variables['top_level'][:]=tl

# %%
nc.close()

# %%
nc = Dataset('/work/n01/n01/jdha/scratch/test_deploy_cray/nemo/cfgs/se-eORCA025/EXP_TEST/domain_cfg_mes.nc',mode='a')

# %%
plt.pcolormesh(nc.variables['top_level'][0,0:300,0:300])

# %%
tl = nc.variables['bottom_level'][:]
tl[0,5:200:25,200] = 5
nc.variables['bottom_level'][:]=tl

# %%
nc.close()
